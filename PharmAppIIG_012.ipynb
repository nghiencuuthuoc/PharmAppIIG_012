# %% [markdown]
# <a href="https://github.com/nghiencuuthuoc/PharmApp/PharmApp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# ![](https://raw.githubusercontent.com/nghiencuuthuoc/PharmApp/master/PharmApp-logo.png)
# # PharmApp - Drug Discovery and Development
# Copyright 2022 | Nghiên Cứu Thuốc | RD Pharma Plus
#
# Email: nghiencuuthuoc@gmail.com | info@nghiencuuthuoc.com
#
# Web: http://www.nghiencuuthuoc.com
#
# See more: https://twitter.com/nghiencuuthuoc | https://facebook.com/nghiencuuthuoc | https://github.com/nghiencuuthuoc/PharmApp

# %% [markdown]
# # PharmAppIIG

# %% [markdown]
# ## Get inactive ingredient one name

# %%
# input name
drug_raw_temp = str(input("Enter name: "))
drug_name = drug_raw_temp.lower().replace(' ', '')
# Save file inactive_ingredient_list.txt
try:
    drug = drug_name
    import src.pharmappiig012 as pa
    print(drug)
    pa.get_inactive_ingredient(name_drug=drug)
except:
    pass
# view data
import os
drug_name_csv = drug_name + "_inactive_ingredient_list.txt"
drug_name_csv_path = os.path.join('iigdata', drug_name_csv)
if os.path.isfile(drug_name_csv_path):
    import pandas as pd
    pd.set_option("display.max_rows", None, "display.max_columns", None)
    df_iig = pd.read_csv(drug_name_csv_path)
else:
    print(f'{drug_name} is not on Dailymed!')
df_iig
# Out:
# Enter name: Calcitriol
# calcitriol
# Output file done!
# Linklist file done!
# Output1 file done!
# Find 3 pages of calcitriol on DailyMed
# Save link DailyMed of calcitriol on file linklistdata\calcitriol_linklist.txt in folder E:\DD\PharmApp\PharmAppIIG
# Saved file linklist done!
# Save link DailyMed of calcitriol on file linklistdata\calcitriol_linklist.txt in folder E:\DD\PharmApp\PharmAppIIG
# Saved file linklist done!
# Save link DailyMed of calcitriol on file linklistdata\calcitriol_linklist.txt in folder E:\DD\PharmApp\PharmAppIIG
# Saved file linklist done!
# Save inactive ingredient of calcitriol on file iigdata\calcitriol_inactive_ingredient_list.txt infolder E:\DD\PharmApp\PharmAppIIG
#        MainDrug         NDC       Strength  \
# 0    calcitriol   64380-723        0.25 ug
# 1    calcitriol   64380-723        0.25 ug
# 2    calcitriol   64380-723        0.25 ug
# 3    calcitriol   64380-723        0.25 ug
# 4    calcitriol   64380-723        0.25 ug
# 5    calcitriol   64380-723        0.25 ug
# 6    calcitriol   64380-723        0.25 ug
# 7    calcitriol   64380-723        0.25 ug
# 8    calcitriol   64380-724         0.5 ug
# 9    calcitriol   64380-724         0.5 ug
# 10   calcitriol   64380-724         0.5 ug
# 11   calcitriol   64380-724         0.5 ug
# 12   calcitriol   64380-724         0.5 ug
# 13   calcitriol   64380-724         0.5 ug
# 14   calcitriol   64380-724         0.5 ug
# 15   calcitriol   64380-724         0.5 ug
# 16   calcitriol   65162-519        0.25 ug
# 17   calcitriol   65162-519        0.25 ug
# 18   calcitriol   65162-519        0.25 ug
# 19   calcitriol   65162-519        0.25 ug
# 20   calcitriol   65162-519        0.25 ug
# 21   calcitriol   65162-519        0.25 ug
# 22   calcitriol   65162-519        0.25 ug
# 23   calcitriol   65162-519        0.25 ug
# 24   calcitriol   65162-519        0.25 ug
# 25   calcitriol   65162-519        0.25 ug
# 26   calcitriol   65162-576         0.5 ug
# 225  calcitriol   0004-0144         0.5 ug
# 226  calcitriol   0004-0144         0.5 ug
# 227  calcitriol   0004-0144         0.5 ug
# 228  calcitriol   0004-0144         0.5 ug
# 229  calcitriol   0004-0144         0.5 ug
# 230  calcitriol   0004-0144         0.5 ug
# 231  calcitriol   0004-9115  1 ug  in 1 mL
# 232  calcitriol   0004-9115  1 ug  in 1 mL
# 233  calcitriol   0004-9115  1 ug  in 1 mL
# 234   64380-723  17856-0723        0.25 ug
# 235   64380-723  17856-0723        0.25 ug
# 236   64380-723  17856-0723        0.25 ug
# 237   64380-723  17856-0723        0.25 ug
# 238   64380-723  17856-0723        0.25 ug
# 239   64380-723  17856-0723        0.25 ug
# 240   64380-723  17856-0723        0.25 ug
# 241   64380-723  17856-0723        0.25 ug
# 242   64380-723  17856-0723        0.25 ug
# 243   64380-723   60687-345        0.25 ug
# 244   64380-723   60687-345        0.25 ug
# 245   64380-723   60687-345        0.25 ug
# 246   64380-723   60687-345        0.25 ug
# 247   64380-723   60687-345        0.25 ug
# 248   64380-723   60687-345        0.25 ug
# 249   64380-723   60687-345        0.25 ug
# 250   64380-723   60687-345        0.25 ug
# 251   64380-723   60687-345        0.25 ug
# 252   60687-345  55154-8186        0.25 ug
# 253   60687-345  55154-8186        0.25 ug
# 254   60687-345  55154-8186        0.25 ug
# 255   60687-345  55154-8186        0.25 ug
# 256   60687-345  55154-8186        0.25 ug
# 257   60687-345  55154-8186        0.25 ug
# 258   60687-345  55154-8186        0.25 ug
# 259   60687-345  55154-8186        0.25 ug
# 260   60687-345  55154-8186        0.25 ug
# 261   63304-239   43353-138        0.25 ug
# 262   63304-239   43353-138        0.25 ug
# 263   63304-239   43353-138        0.25 ug
# 264   63304-239   43353-138        0.25 ug
# 265   63304-239   43353-138        0.25 ug
# 266   63304-239   43353-138        0.25 ug
# 267   63304-239   43353-138        0.25 ug
# 268   63304-239   43353-138        0.25 ug
# 269   0054-0007   43353-034        0.25 ug
# 270   0054-0007   43353-034        0.25 ug
# 271   0054-0007   43353-034        0.25 ug
# 272   0054-0007   43353-034        0.25 ug
# 273   0054-0007   43353-034        0.25 ug
# 274   0054-0007   43353-034        0.25 ug
# 275   0054-0007   43353-034        0.25 ug
# 276   0054-0007   43353-034        0.25 ug
# 277   0054-0007   43353-034        0.25 ug
# 278   0054-0007   43353-034        0.25 ug
# 279   72789-058   71610-521        0.25 ug
# 280   72789-058   71610-521        0.25 ug
# 281   72789-058   71610-521        0.25 ug
# 282   72789-058   71610-521        0.25 ug
# 283   72789-058   71610-521        0.25 ug
# 284   72789-058   71610-521        0.25 ug
# 285   72789-058   71610-521        0.25 ug
# 286   72789-058   71610-521        0.25 ug
# 287   72789-058   71610-521        0.25 ug
# 288   72789-058   71610-521        0.25 ug
# 289   63304-239  68151-0088        0.25 ug
# 290   63304-239  68151-0088        0.25 ug
# 291   63304-239  68151-0088        0.25 ug
# 292   63304-239  68151-0088        0.25 ug
# 293   63304-239  68151-0088        0.25 ug
# 294   63304-239  68151-0088        0.25 ug
# 295   63304-239  68151-0088        0.25 ug
# 505  calcitriol   0299-2012   3 ug  in 1 g
# 506  calcitriol   0299-2012   3 ug  in 1 g
# 507  calcitriol   0299-2012   3 ug  in 1 g
# 508   30698-143   43353-633        0.25 ug
# 509   30698-143   43353-633        0.25 ug
# 510   30698-143   43353-633        0.25 ug
# 511   30698-143   43353-633        0.25 ug
# 512   30698-143   43353-633        0.25 ug
# 513   30698-143   43353-633        0.25 ug
# 514   30698-143   43353-633        0.25 ug
# 515   30698-143   43353-633        0.25 ug
#
#                               Formulation  \
# 0               capsules 0.25 mcg capsule
# 1               capsules 0.25 mcg capsule
# 2               capsules 0.25 mcg capsule
# 3               capsules 0.25 mcg capsule
# 4               capsules 0.25 mcg capsule
# 5               capsules 0.25 mcg capsule
# 6               capsules 0.25 mcg capsule
# 7               capsules 0.25 mcg capsule
# 8                capsules 0.5 mcg capsule
# 9                capsules 0.5 mcg capsule
# 10               capsules 0.5 mcg capsule
# 11               capsules 0.5 mcg capsule
# 12               capsules 0.5 mcg capsule
# 13               capsules 0.5 mcg capsule
# 14               capsules 0.5 mcg capsule
# 15               capsules 0.5 mcg capsule
# 16                                capsule
# 17                                capsule
# 18                                capsule
# 19                                capsule
# 20                                capsule
# 21                                capsule
# 22                                capsule
# 23                                capsule
# 24                                capsule
# 25                                capsule
# 26                                capsule
# 27                                capsule
# 28                                capsule
# 29                                capsule
# 30                                capsule
# 31                                capsule
# 32                                capsule
# 33                                capsule
# 34                                capsule
# 35                                capsule
# 36                                capsule
# 37                                capsule
# 38                                capsule
# 39                                capsule
# 40                                capsule
# 41                                capsule
# 42                                capsule
# 43                                capsule
# 44                                capsule
# 45                                capsule
# 46                                capsule
# 47                                capsule
# 48                                capsule
# 49                                capsule
# 50                                capsule
# 51                                capsule
# 52                                capsule
# 53                                capsule
# 54                                capsule
# 55                                capsule
# 56                                capsule
# 57                                capsule
# 58                                capsule
# 59                                capsule
# 60                                capsule
# 61                                capsule
# 62                                capsule
# 63                                capsule
# 64                                capsule
# 65                                capsule
# 66                                capsule
# 67                                capsule
# 68                               solution
# 69                               solution
# 70                               solution
# 71                                capsule
# 72                                capsule
# 73                                capsule
# 74                                capsule
# 75                                capsule
# 76                                capsule
# 77                                capsule
# 78                                capsule
# 79                                capsule
# 80                 capsule, liquid filled
# 81                 capsule, liquid filled
# 82                 capsule, liquid filled
# 83                 capsule, liquid filled
# 84                 capsule, liquid filled
# 85                 capsule, liquid filled
# 86                 capsule, liquid filled
# 87                 capsule, liquid filled
# 88                 capsule, liquid filled
# 89                 capsule, liquid filled
# 90                 capsule, liquid filled
# 91                 capsule, liquid filled
# 92                 capsule, liquid filled
# 93                 capsule, liquid filled
# 94                 capsule, liquid filled
# 95                 capsule, liquid filled
# 96                 capsule, liquid filled
# 97                 capsule, liquid filled
# 98                 capsule, liquid filled
# 99                 capsule, liquid filled
# 100                capsule, liquid filled
# 101                capsule, liquid filled
# 102                capsule, liquid filled
# 103                capsule, liquid filled
# 104                capsule, liquid filled
# 105                capsule, liquid filled
# 106                capsule, liquid filled
# 107                capsule, liquid filled
# 108                capsule, liquid filled
# 109                capsule, liquid filled
# 110                capsule, liquid filled
# 111                capsule, liquid filled
# 112                capsule, liquid filled
# 113                capsule, liquid filled
# 114                capsule, liquid filled
# 115                capsule, liquid filled
# 116                capsule, liquid filled
# 117                capsule, liquid filled
# 118                capsule, liquid filled
# 119                capsule, liquid filled
# 120                capsule, liquid filled
# 121                capsule, liquid filled
# 122                capsule, liquid filled
# 123                capsule, liquid filled
# 124                capsule, liquid filled
# 125                capsule, liquid filled
# 126                capsule, liquid filled
# 127                capsule, liquid filled
# 128                capsule, liquid filled
# 129                capsule, liquid filled
# 130                capsule, liquid filled
# 131                capsule, liquid filled
# 132                capsule, liquid filled
# 133                capsule, liquid filled
# 134                capsule, liquid filled
# 135                capsule, liquid filled
# 136                capsule, liquid filled
# 137                capsule, liquid filled
# 138                capsule, liquid filled
# 139                capsule, liquid filled
# 140                capsule, liquid filled
# 141                capsule, liquid filled
# 142                capsule, liquid filled
# 143                capsule, liquid filled
# 144                capsule, liquid filled
# 145                capsule, liquid filled
# 146                capsule, liquid filled
# 147                capsule, liquid filled
# 148                capsule, liquid filled
# 149                capsule, liquid filled
# 150                capsule, liquid filled
# 151                capsule, liquid filled
# 152                capsule, liquid filled
# 153                capsule, liquid filled
# 154                capsule, liquid filled
# 155                capsule, liquid filled
# 156                capsule, liquid filled
# 157                capsule, liquid filled
# 158                capsule, liquid filled
# 159                             injection
# 160                             injection
# 161                             injection
# 162                             injection
# 163                             injection
# 164                             injection
# 165                             injection
# 166                             injection
# 167                             injection
# 168                             injection
# 169                             injection
# 170                             injection
# 171                             injection
# 172                             injection
# 173                             injection
# 174                             injection
# 175                             injection
# 176                             injection
# 177                             injection
# 178                             injection
# 179                             injection
# 180                             injection
# 181                             injection
# 182                             injection
# 183                             injection
# 184                             injection
# 185                             injection
# 186                             injection
# 187                             injection
# 188                             injection
# 189                             injection
# 190                             injection
# 191                             injection
# 192                             injection
# 193                             injection
# 194                              ointment
# 195                              ointment
# 196                              ointment
# 197                              solution
# 198                              solution
# 199                              solution
# 200                              solution
# 201                              solution
# 202                              solution
# 203                              solution
# 204                              solution
# 205                              solution
# 206                              solution
# 207                              solution
# 208                              solution
# 209                              solution
# 210                capsule, liquid filled
# 211                capsule, liquid filled
# 212                capsule, liquid filled
# 213                capsule, liquid filled
# 214                capsule, liquid filled
# 215                capsule, liquid filled
# 216                capsule, liquid filled
# 217                capsule, liquid filled
# 218                capsule, liquid filled
# 219                capsule, liquid filled
# 220                capsule, liquid filled
# 221                capsule, liquid filled
# 222                capsule, liquid filled
# 223                capsule, liquid filled
# 224                capsule, liquid filled
# 225                capsule, liquid filled
# 226                capsule, liquid filled
# 227                capsule, liquid filled
# 228                capsule, liquid filled
# 229                capsule, liquid filled
# 230                capsule, liquid filled
# 231                              solution
# 232                              solution
# 233                              solution
# 234           calcitriol 0.25 mcg capsule
# 235           calcitriol 0.25 mcg capsule
# 236           calcitriol 0.25 mcg capsule
# 237           calcitriol 0.25 mcg capsule
# 238           calcitriol 0.25 mcg capsule
# 239           calcitriol 0.25 mcg capsule
# 411     calcitriol capsule, liquid filled
# 412     calcitriol capsule, liquid filled
# 413     calcitriol capsule, liquid filled
# 414     calcitriol capsule, liquid filled
# 415     calcitriol capsule, liquid filled
# 416     calcitriol capsule, liquid filled
# 417     calcitriol capsule, liquid filled
# 418     calcitriol capsule, liquid filled
# 419     calcitriol capsule, liquid filled
# 420     calcitriol capsule, liquid filled
# 421     calcitriol capsule, liquid filled
# 422     calcitriol capsule, liquid filled
# 423     calcitriol capsule, liquid filled
# 424     calcitriol capsule, liquid filled
# 425     calcitriol capsule, liquid filled
# 426     calcitriol capsule, liquid filled
# 427     calcitriol capsule, liquid filled
# 428     calcitriol capsule, liquid filled
# 429     calcitriol capsule, liquid filled
# 430     calcitriol capsule, liquid filled
# 431     calcitriol capsule, liquid filled
# 432     calcitriol capsule, liquid filled
# 433     calcitriol capsule, liquid filled
# 434     calcitriol capsule, liquid filled
# 435     calcitriol capsule, liquid filled
# 436     calcitriol capsule, liquid filled
# 437     calcitriol capsule, liquid filled
# 438     calcitriol capsule, liquid filled
# 439     calcitriol capsule, liquid filled
# 440     calcitriol capsule, liquid filled
# 441     calcitriol capsule, liquid filled
# 442     calcitriol capsule, liquid filled
# 443     calcitriol capsule, liquid filled
# 444     calcitriol capsule, liquid filled
# 445     calcitriol capsule, liquid filled
# 446     calcitriol capsule, liquid filled
# 447     calcitriol capsule, liquid filled
# 448     calcitriol capsule, liquid filled
# 449     calcitriol capsule, liquid filled
# 450     calcitriol capsule, liquid filled
# 451     calcitriol capsule, liquid filled
# 452     calcitriol capsule, liquid filled
# 453     calcitriol capsule, liquid filled
# 454     calcitriol capsule, liquid filled
# 455     calcitriol capsule, liquid filled
# 456     calcitriol capsule, liquid filled
# 457     calcitriol capsule, liquid filled
# 458     calcitriol capsule, liquid filled
# 459     calcitriol capsule, liquid filled
# 460     calcitriol capsule, liquid filled
# 461     calcitriol capsule, liquid filled
# 462     calcitriol capsule, liquid filled
# 463     calcitriol capsule, liquid filled
# 464     calcitriol capsule, liquid filled
# 465                    calcitriol capsule
# 466                    calcitriol capsule
# 467                    calcitriol capsule
# 468                    calcitriol capsule
# 469                    calcitriol capsule
# 470                    calcitriol capsule
# 471                    calcitriol capsule
# 472                    calcitriol capsule
# 473                    calcitriol capsule
# 474                    calcitriol capsule
# 475        calcitriol injection, solution
# 476        calcitriol injection, solution
# 477        calcitriol injection, solution
# 478        calcitriol injection, solution
# 479        calcitriol injection, solution
# 480        calcitriol injection, solution
# 481        calcitriol injection, solution
# 482        calcitriol injection, solution
# 483                   calcitriol solution
# 484                   calcitriol solution
# 485                   calcitriol solution
# 486                   calcitriol solution
# 487               capsule, gelatin coated
# 488               capsule, gelatin coated
# 489               capsule, gelatin coated
# 490               capsule, gelatin coated
# 491               capsule, gelatin coated
# 492               capsule, gelatin coated
# 493               capsule, gelatin coated
# 494               capsule, gelatin coated
# 495               capsule, gelatin coated
# 496               capsule, gelatin coated
# 497               capsule, gelatin coated
# 498               capsule, gelatin coated
# 499               capsule, gelatin coated
# 500               capsule, gelatin coated
# 501               capsule, gelatin coated
# 502                              solution
# 503                              solution
# 504                              solution
# 505                              ointment
# 506                              ointment
# 507                              ointment
# 508    calcitriol capsule, gelatin coated
# 509    calcitriol capsule, gelatin coated
# 510    calcitriol capsule, gelatin coated
# 511    calcitriol capsule, gelatin coated
# 512    calcitriol capsule, gelatin coated
# 513    calcitriol capsule, gelatin coated
# 514    calcitriol capsule, gelatin coated
# 515    calcitriol capsule, gelatin coated
#
#                                        Inactive
# 0                      BUTYLATED HYDROXYANISOLE
# 1                      BUTYLATED HYDROXYTOLUENE
# 2                    MEDIUM-CHAIN TRIGLYCERIDES
# 3                                      GLYCERIN
# ...
# 196                                  PETROLATUM
# 197                    BUTYLATED HYDROXYANISOLE
# 198                    BUTYLATED HYDROXYTOLUENE
# 199                   OMEGA-3-ACID ETHYL ESTERS
# 200                              Polysorbate 20
# 201                             sodium chloride
# 202                            sodium ascorbate
# 203         dibasic sodium phosphate, anhydrous
# 204       monobasic sodium phosphate, dihydrate
# 205                 edetate disodium, dihydrate
# 206                                       water
# 207                  MEDIUM-CHAIN TRIGLYCERIDES
# 208                    BUTYLATED HYDROXYANISOLE
# 209                    BUTYLATED HYDROXYTOLUENE
# 210                    butylated hydroxyanisole
# 211                    butylated hydroxytoluene
# 212    fractionated triglyceride of coconut oil
# 213                                     gelatin
# 214                                    glycerin
# 215                               methylparaben
# 216                               propylparaben
# 217                                    sorbitol
# 218                       FD&amp;C Yellow No. 6
# 219                            titanium dioxide
# 220                    butylated hydroxyanisole
# 221                    butylated hydroxytoluene
# 222    fractionated triglyceride of coconut oil
# 223                                     gelatin
# 224                                    glycerin
# 225                               methylparaben
# 226                               propylparaben
# 227                                    sorbitol
# 228                          FD&amp;C Red No. 3
# 229                       FD&amp;C Yellow No. 6
# 230                            titanium dioxide
# 231                    butylated hydroxyanisole
# 232                    butylated hydroxytoluene
# 233  fractionated triglyceride of palm seed oil
# 234                                  CALCITRIOL
# 235                    BUTYLATED HYDROXYANISOLE
# 236                    BUTYLATED HYDROXYTOLUENE
# 237                  MEDIUM-CHAIN TRIGLYCERIDES
# 238                                    GLYCERIN
# 239                                    SORBITOL
# 240                       FD&amp;C YELLOW NO. 6
# 241                          FD&amp;C RED NO. 3
# 242                            TITANIUM DIOXIDE
# 243                                  CALCITRIOL
# 244                    BUTYLATED HYDROXYANISOLE
# 245                    BUTYLATED HYDROXYTOLUENE
# 246                  MEDIUM-CHAIN TRIGLYCERIDES
# 247                                    GLYCERIN
# 248                                    SORBITOL
# 249                       FD&amp;C YELLOW NO. 6
# 250                          FD&amp;C RED NO. 3
# 251                            TITANIUM DIOXIDE
# 252                                  CALCITRIOL
# 253                    BUTYLATED HYDROXYANISOLE
# 254                    BUTYLATED HYDROXYTOLUENE
# 255                  MEDIUM-CHAIN TRIGLYCERIDES
# 256                                    GLYCERIN
# 257                                    SORBITOL
# 258                       FD&amp;C YELLOW NO. 6
# 259                          FD&amp;C RED NO. 3
# 260                            TITANIUM DIOXIDE
# 261                                  CALCITRIOL
# 262                    BUTYLATED HYDROXYANISOLE
# 263                    BUTYLATED HYDROXYTOLUENE
# 264                                 COCONUT OIL
# 265                                    GLYCERIN
# 266                                    SORBITOL
# 267                       FD&amp;C YELLOW NO. 6
# 268                            TITANIUM DIOXIDE
# 269                                  CALCITRIOL
# 270                    BUTYLATED HYDROXYANISOLE
# 271                    BUTYLATED HYDROXYTOLUENE
# 272                                 COCONUT OIL
# 273                       FD&amp;C YELLOW NO. 5
# 274                       FD&amp;C YELLOW NO. 6
# 275                        GELATIN, UNSPECIFIED
# 276                                    GLYCERIN
# 277                         FERROSOFERRIC OXIDE
# 278                            TITANIUM DIOXIDE
# 279                                  CALCITRIOL
# 280                    BUTYLATED HYDROXYANISOLE
# 281                    BUTYLATED HYDROXYTOLUENE
# 282                                 COCONUT OIL
# 283                       FD&amp;C YELLOW NO. 5
# 284                       FD&amp;C YELLOW NO. 6
# 285                        GELATIN, UNSPECIFIED
# 286                                    GLYCERIN
# 287                         FERROSOFERRIC OXIDE
# 288                            TITANIUM DIOXIDE
# 289                                  CALCITRIOL
# 290                    BUTYLATED HYDROXYANISOLE
# 291                    BUTYLATED HYDROXYTOLUENE
# 292                                 COCONUT OIL
# 293                                    GLYCERIN
# 294                                    SORBITOL
# 295                       FD&amp;C YELLOW NO. 6
# 296                            TITANIUM DIOXIDE
# 297                                  CALCITRIOL
# 298                    BUTYLATED HYDROXYANISOLE
# 299                    BUTYLATED HYDROXYTOLUENE
# 300                                 COCONUT OIL
# 301                                    GLYCERIN
# 302                                    SORBITOL
# 303                       FD&amp;C YELLOW NO. 6
# 304                            TITANIUM DIOXIDE
# 305                                  CALCITRIOL
# 306                    BUTYLATED HYDROXYANISOLE
# 307                    BUTYLATED HYDROXYTOLUENE
# 308                  MEDIUM-CHAIN TRIGLYCERIDES
# 309                                     GELATIN
# 310                                    GLYCERIN
# 311                                    SORBITOL
# 312                                    SORBITAN
# 313                                    MANNITOL
# 314                                       WATER
# 315                       FD&amp;C YELLOW NO. 6
# 316                         FD&amp;C RED NO. 40
# 317                            TITANIUM DIOXIDE
# 318                         FERROSOFERRIC OXIDE
# 319                                  CALCITRIOL
# 320                    BUTYLATED HYDROXYANISOLE
# 321                    BUTYLATED HYDROXYTOLUENE
# 322                  MEDIUM-CHAIN TRIGLYCERIDES
# 323                                     GELATIN
# 324                                    GLYCERIN
# 325                                    SORBITOL
# 326                                    SORBITAN
# 327                                    MANNITOL
# 328                                       WATER
# 329                       FD&amp;C YELLOW NO. 6
# 330                         FD&amp;C RED NO. 40
# 331                            TITANIUM DIOXIDE
# 332                         FERROSOFERRIC OXIDE
# 333                                  CALCITRIOL
# 334                    BUTYLATED HYDROXYANISOLE
# 335                    BUTYLATED HYDROXYTOLUENE
# 336                  MEDIUM-CHAIN TRIGLYCERIDES
# 337                        GELATIN, UNSPECIFIED
# 338                                    GLYCERIN
# 339                                    MANNITOL
# 340                            FERRIC OXIDE RED
# 341                                    SORBITOL
# 342                            TITANIUM DIOXIDE
# 343                         FERRIC OXIDE YELLOW
# 344                            PROPYLENE GLYCOL
# 345                                  CALCITRIOL
# 346                    BUTYLATED HYDROXYANISOLE
# 347                    BUTYLATED HYDROXYTOLUENE
# 348                  MEDIUM-CHAIN TRIGLYCERIDES
# 349                        GELATIN, UNSPECIFIED
# 350                                    GLYCERIN
# 351                                    MANNITOL
# 352                            FERRIC OXIDE RED
# 353                                    SORBITOL
# 354                            TITANIUM DIOXIDE
# 355                         FERRIC OXIDE YELLOW
# 356                            PROPYLENE GLYCOL
# 357                                  CALCITRIOL
# 358                    BUTYLATED HYDROXYANISOLE
# 359                    BUTYLATED HYDROXYTOLUENE
# 360                  MEDIUM-CHAIN TRIGLYCERIDES
# 361                        GELATIN, UNSPECIFIED
# 362                                    GLYCERIN
# 363                                    SORBITOL
# 364                                    SORBITAN
# 365                                    MANNITOL
# 366                                       WATER
# 367                       FD&amp;C YELLOW NO. 6
# 368                         FD&amp;C RED NO. 40
# 369                            TITANIUM DIOXIDE
# 370                         FERROSOFERRIC OXIDE
# 371                                  CALCITRIOL
# 372                    BUTYLATED HYDROXYANISOLE
# 373                    BUTYLATED HYDROXYTOLUENE
# 374                  MEDIUM-CHAIN TRIGLYCERIDES
# 375                        GELATIN, UNSPECIFIED
# 376                                    GLYCERIN
# 377                                    SORBITOL
# 378                                    SORBITAN
# 379                                    MANNITOL
# 380                                       WATER
# 381                       FD&amp;C YELLOW NO. 6
# 382                         FD&amp;C RED NO. 40
# 383                            TITANIUM DIOXIDE
# 384                         FERROSOFERRIC OXIDE
# 385                                  CALCITRIOL
# 386                    BUTYLATED HYDROXYANISOLE
# 387                    BUTYLATED HYDROXYTOLUENE
# 388                  MEDIUM-CHAIN TRIGLYCERIDES
# 389                        GELATIN, UNSPECIFIED
# 390                                    GLYCERIN
# 391                                    MANNITOL
# 392                            FERRIC OXIDE RED
# 393                                    SORBITOL
# 394                            TITANIUM DIOXIDE
# 395                         FERRIC OXIDE YELLOW
# 396                            PROPYLENE GLYCOL
# 397                                  CALCITRIOL
# 398                    BUTYLATED HYDROXYANISOLE
# 399                    BUTYLATED HYDROXYTOLUENE
# 400                  MEDIUM-CHAIN TRIGLYCERIDES
# 401                        GELATIN, UNSPECIFIED
# 402                                    GLYCERIN
# 403                                    MANNITOL
# 404                            FERRIC OXIDE RED
# 405                                    SORBITOL
# 406                            TITANIUM DIOXIDE
# 407                         FERRIC OXIDE YELLOW
# 408                            PROPYLENE GLYCOL
# 409                                  CALCITRIOL
# 410                    BUTYLATED HYDROXYANISOLE
# 411                    BUTYLATED HYDROXYTOLUENE
# 412                  MEDIUM-CHAIN TRIGLYCERIDES
# 413                                     GELATIN
# 414                                    GLYCERIN
# 415                                    SORBITOL
# 416                                    SORBITAN
# 417                                    MANNITOL
# 418                                       WATER
# 419                       FD&amp;C YELLOW NO. 6
# 420                         FD&amp;C RED NO. 40
# 421                            TITANIUM DIOXIDE
# 422                         FERROSOFERRIC OXIDE
# 423                                  CALCITRIOL
# 424                    BUTYLATED HYDROXYANISOLE
# 425                    BUTYLATED HYDROXYTOLUENE
# 426                  MEDIUM-CHAIN TRIGLYCERIDES
# 427                                     GELATIN
# 428                                    GLYCERIN
# 429                                    SORBITOL
# 430                                    SORBITAN
# 431                                    MANNITOL
# 432                                       WATER
# 433                       FD&amp;C YELLOW NO. 6
# 434                         FD&amp;C RED NO. 40
# 435                            TITANIUM DIOXIDE
# 436                         FERROSOFERRIC OXIDE
# 437                                  CALCITRIOL
# 438                    BUTYLATED HYDROXYANISOLE
# 439                    BUTYLATED HYDROXYTOLUENE
# 440                                     GELATIN
# 441                                    GLYCERIN
# 442                                    MANNITOL
# 443                            FERRIC OXIDE RED
# 444                                    SORBITOL
# 445                            TITANIUM DIOXIDE
# 446                         FERRIC OXIDE YELLOW
# 447                                     AMMONIA
# 448                           ISOPROPYL ALCOHOL
# 449                            PROPYLENE GLYCOL
# 450                                     SHELLAC
# 451                                  CALCITRIOL
# 452                    BUTYLATED HYDROXYANISOLE
# 453                    BUTYLATED HYDROXYTOLUENE
# 454                                     GELATIN
# 455                                    GLYCERIN
# 456                                    MANNITOL
# 457                            FERRIC OXIDE RED
# 458                                    SORBITOL
# 459                            TITANIUM DIOXIDE
# 460                         FERRIC OXIDE YELLOW
# 461                                     AMMONIA
# 462                           ISOPROPYL ALCOHOL
# 463                            PROPYLENE GLYCOL
# 464                                     SHELLAC
# 465                                  CALCITRIOL
# 466                    BUTYLATED HYDROXYANISOLE
# 467                    BUTYLATED HYDROXYTOLUENE
# 468                                 COCONUT OIL
# 469                       FD&amp;C YELLOW NO. 5
# 470                       FD&amp;C YELLOW NO. 6
# 471                        GELATIN, UNSPECIFIED
# 472                                    GLYCERIN
# 473                         FERROSOFERRIC OXIDE
# 474                            TITANIUM DIOXIDE
# 475                                  CALCITRIOL
# 476                              POLYSORBATE 20
# 477                             SODIUM CHLORIDE
# 478                            SODIUM ASCORBATE
# 479         SODIUM PHOSPHATE, DIBASIC ANHYDROUS
# 480    SODIUM PHOSPHATE, MONOBASIC, MONOHYDRATE
# 481                            EDETATE DISODIUM
# 482                                       WATER
# 483                                  CALCITRIOL
# 484                    BUTYLATED HYDROXYANISOLE
# 485                    BUTYLATED HYDROXYTOLUENE
# 486                   OMEGA-3-ACID ETHYL ESTERS
# 487                    BUTYLATED HYDROXYANISOLE
# 488                    BUTYLATED HYDROXYTOLUENE
# 489                                 COCONUT OIL
# 490                                    GLYCERIN
# 491                                    SORBITOL
# 492                       FD&amp;C YELLOW NO. 6
# 493                            TITANIUM DIOXIDE
# 494                    BUTYLATED HYDROXYANISOLE
# 495                    BUTYLATED HYDROXYTOLUENE
# 496                                 COCONUT OIL
# 497                                    GLYCERIN
# 498                                    SORBITOL
# 499                          FD&amp;C RED NO. 3
# 500                       FD&amp;C YELLOW NO. 6
# 501                            TITANIUM DIOXIDE
# 502                    BUTYLATED HYDROXYANISOLE
# 503                    BUTYLATED HYDROXYTOLUENE
# 504                                    PALM OIL
# 505                                 mineral oil
# 506                     .ALPHA.-TOCOPHEROL, DL-
# 507                                  Petrolatum
# 508                                  CALCITRIOL
# 509                    BUTYLATED HYDROXYANISOLE
# 510                    BUTYLATED HYDROXYTOLUENE
# 511                                 COCONUT OIL
# 512                                    GLYCERIN
# 513                                    SORBITOL
# 514                       FD&amp;C YELLOW NO. 6
# 515                            TITANIUM DIOXIDE

# %% [markdown]
# ## Extract NDC to Urls, Open webbrowser

# %%
import numpy as np
import webbrowser  
ndc_arr = pd.DataFrame(df_iig,columns=['NDC']).to_numpy()
unique_ndc_arr = np.unique(ndc_arr)
ndcs = unique_ndc_arr.tolist()
for ndc in ndcs:
    url = "https://ndclist.com/ndc/" + ndc
    print(url)
    webbrowser.open_new_tab(url)

# %%
# Enter 1 NDC Code Ex. 68511-993
import webbrowser
ndc = str(input("Enter NDC Code: "))
url = "https://ndclist.com/ndc/" + ndc
print(url)
webbrowser.open_new_tab(url)
# Out:
# Enter NDC Code:
# https://ndclist.com/ndc/
# True

# %% [markdown]
# ## View data - Dev

# %%
df_iig

# %%
from pivottablejs import pivot_ui

pivot_ui(df_iig)

# %%
# !pip install pandasgui

# %%
from pandasgui import show

show(df_iig)

# %%
import tabloo

tabloo.show(df_iig)

# %% [markdown]
# ## Get iig for multi name

# %%
# Input multi names with (" ")
drugs_raw_temp = str(input("Enter name: "))

# Save file inactive_ingredient_list.txt
try:
    # drug name
    drugs_raw = drugs_raw_temp
    drugs = drugs_raw.split(" ")
    # get inactive ingredient
    import src.pharmappiig012 as pa
    for drug in drugs:
        print(drug)
        pa.get_inactive_ingredient(name_drug=drug)
        print(f'{drug} done!')
        print("+---------------------------+---------------------------+")
        continue
except:
    
#     continue
    pass
# finally:
#     continue

# %% [markdown]
# ## Get iig and view data for multi name

# %%
# Input name
drugs_raw_temp = str(input("Enter name: "))

# Save file inactive_ingredient_list.txt
# drug name
drugs_raw = drugs_raw_temp
drugs = drugs_raw.split(" ")
# get inactive ingredient
import src.pharmappiig012 as pa
for drug in drugs:
    try:
        print(drug)
        pa.get_inactive_ingredient(name_drug=drug)
        print(f'{drug} done!')
        print("+---------------------------+---------------------------+")
    except:
        print(f'{drug} no found in DailyMed or run error!')
        print("+---------------------------+---------------------------+")
# # view multi drugs
# for drug in drugs:
#     drug_raw_csv = drug + "_inactive_ingredient_list.txt"
#     # view data
#     import pandas as pd
#     pd.set_option("display.max_rows", None, "display.max_columns", None)
#     df_iig = pd.read_csv(drug_raw_csv)
#     print(df_iig)
    
# view data
for drug_name in drugs:
    import os
    drug_name_csv = drug_name + "_inactive_ingredient_list.txt"
    drug_name_csv_path = os.path.join('iigdata', drug_name_csv)
    if os.path.isfile(drug_name_csv_path):
        import pandas as pd
        pd.set_option("display.max_rows", None, "display.max_columns", None)
        df_iig = pd.read_csv(drug_name_csv_path)
    else:
        print(f'{drug_name_temp} is not on Dailymed!')
    print(df_iig)

# %% [markdown]
# ## Extract NDC to Urls, Open webbrowser

# %%
import numpy as np
import webbrowser  
ndc_arr = pd.DataFrame(df_iig,columns=['NDC']).to_numpy()
unique_ndc_arr = np.unique(ndc_arr)
ndcs = unique_ndc_arr.tolist()
for ndc in ndcs:
    url = "https://ndclist.com/ndc/" + ndc
    print(url)
    import webbrowser
    webbrowser.open_new_tab(url)
# Out:
# https://ndclist.com/ndc/0029-6080
# https://ndclist.com/ndc/0029-6086
# https://ndclist.com/ndc/43598-003
# https://ndclist.com/ndc/43598-004
# https://ndclist.com/ndc/43598-006
# https://ndclist.com/ndc/43598-012
# https://ndclist.com/ndc/43598-018
# https://ndclist.com/ndc/43598-021
# https://ndclist.com/ndc/54868-0387
# https://ndclist.com/ndc/54868-4735
# https://ndclist.com/ndc/61919-391

# %% [markdown]
# ## Extract Inactive and Analysis  - Dev

# %%
import numpy as np
inactive_arr = pd.DataFrame(df_iig,columns=['Inactive']).to_numpy()
unique_inactive_arr = np.unique(inactive_arr)
inactives = unique_inactive_arr.tolist()
# inactives

# %%
len(inactive_arr)
# Out:
# 875

# %%
type(inactive_arr)
# Out:
# numpy.ndarray

# %%
len(unique_inactive_arr)
# Out:
# 103

# %%
type(unique_inactive_arr)
# Out:
# numpy.ndarray

# %%
len(inactives)
# Out:
# 103

# %%
type(inactives)
# Out:
# list

# %% [markdown]
# ## View data with the name

# %%
# input name ex. albuterol
name_raw_temp = str(input("Enter name: "))
drug_name = name_raw_temp.lower().replace(' ', '')

# view data
import os
drug_name_csv = drug_name + "_inactive_ingredient_list.txt"
drug_name_csv_path = os.path.join('iigdata', drug_name_csv)
if os.path.isfile(drug_name_csv_path):
    import pandas as pd
    pd.set_option("display.max_rows", None, "display.max_columns", None)
    df_iig = pd.read_csv(drug_name_csv_path)
else:
    print(f'{drug_name_temp} is not on Dailymed!')
df_iig

# %% [markdown]
# ## View Pivot - Dev

# %%
df_iig.pivot_table(values='MainDrug', index='NDC', columns='Inactive', aggfunc=pd.Series.nunique)

# %%
df_iig.pivot_table(values='Inactive', index='NDC', columns='MainDrug', aggfunc=pd.Series.nunique)

# %%
df_iig.pivot_table(values='Inactive', index='MainDrug', columns='Formulation', aggfunc=pd.Series.nunique)

# %% [markdown]
# ## Wordcloud -Dev

# %%
# !pip install wordcloud

# %%
# !git clone https://github.com/amueller/word_cloud.git

# %%
# !cd word_cloud
# !pip install .

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

text = df_iig['Inactive'].values 

wordcloud = WordCloud().generate(str(text))

plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# ## Pubmed Data

# %%
pa.get_pubmed_data()
# Out:
# Data from PubChem for Drug Name: dexamethasone
# CID: 5743
# Isomeric Simles: C[C@@H]1C[C@H]2[C@@H]3CCC4=CC(=O)C=C[C@@]4([C@]3([C@H](C[C@@]2([C@]1(C(=O)CO)O)C)O)F)C
# IUPAC Name: (8S,9R,10S,11S,13S,14S,16R,17R)-9-fluoro-11,17-dihydroxy-17-(2-hydroxyacetyl)-10,13,16-trimethyl-6,7,8,11,12,14,15,16-octahydrocyclopenta[a]phenanthren-3-one
# Molecular formula: C22H29FO5
# Molecular weight: 392.5
# logP: 1.9

# %% [markdown]
# ## Open linklist - Dev

# %%
import pharmapp as pa
pa.open_linklist()

# %% [markdown]
# ## Join all data iig

# %%
import os
import pandas as pd
from glob import glob
all_files = glob(os.path.join('iigdata', "*_inactive_ingredient_list.txt"))
ind_df = (pd.read_csv(f, sep=',') for f in all_files)
df = pd.concat(ind_df, ignore_index=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141750 entries, 0 to 141749
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   MainDrug     141750 non-null  object
#  1   NDC          141750 non-null  object
#  2   Strength     141750 non-null  object
#  3   Formulation  141750 non-null  object
#  4   Inactive     141750 non-null  object
# dtypes: object(5)
# memory usage: 5.4+ MB

# %% [markdown]
# ## zip iig data - dev
